# %% [markdown]
# <a href="https://colab.research.google.com/github/ancantos99/proyectointegrador_ia_grupo8/blob/main/notebooks/%2003_modelado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ENTRENAMIENTO DEL MODELO

# %%
# Clonar el repo del dataset en /content/dataset
# !git lfs install > /dev/null 2>&1
# !git clone https://huggingface.co/datasets/YashJain/UI-Elements-Detection-Dataset /content/dataset > /dev/null 2>&1
print("✅ Git LFS instalado y el dataset clonado en '/content/dataset' de forma silenciosa.")
# Out:
# ✅ Git LFS instalado y el dataset clonado en '/content/dataset' de forma silenciosa.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Instarlar librerias
# !pip install ultralytics > /dev/null 2>&1
print("✅ Ultralytics instalado de forma silenciosa")
# Out:
# ✅ Ultralytics instalado de forma silenciosa

# %%
#Descargo librerias propias
import os
os.makedirs("/content/tools", exist_ok=True)
# !wget -q https://raw.githubusercontent.com/ancantos99/proyectointegrador_ia_grupo8/refs/heads/main/src/tools/YOLODatasetManager.py -O /content/tools/YOLODatasetManager.py > /dev/null 2>&1
# !wget -q https://raw.githubusercontent.com/ancantos99/proyectointegrador_ia_grupo8/refs/heads/main/src/tools/YOLOMetricasVisualizar.py -O /content/tools/YOLOMetricasVisualizar.py > /dev/null 2>&1
# !wget https://raw.githubusercontent.com/ancantos99/proyectointegrador_ia_grupo8/refs/heads/main/src/data_processing.py -O /content/tools/data_processing.py > /dev/null 2>&1
import importlib
import logging
import sys
sys.path.append("/content/tools")
import YOLODatasetManager
import YOLOMetricasVisualizar
import data_processing
#Recarga de archivos - Para actualizar al último Push
importlib.reload(YOLODatasetManager)
importlib.reload(YOLOMetricasVisualizar)
importlib.reload(data_processing)
from YOLODatasetManager import YOLODatasetManager
from YOLOMetricasVisualizar import YOLOMetricasVisualizar
from data_processing import Data_processing
# Configuración global del Login
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', force=True )
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
datasetmanager = YOLODatasetManager("/content/dataset")
datasetmanager.yaml_cambiar_carpeta(split="train",nuevaruta="train")
counts = datasetmanager.compute_class_distribution("train")
print("Distribución:", counts)
##datasetmanager.plot_distribution()
# Out:
# 2025-10-22 23:50:42,243 - YOLODatasetManager - INFO - Ruta Split train actualizada correctamente a train/images en /content/dataset/dataset.yaml.
# Distribución: {'0': 15583, '1': 5101, '2': 354, '3': 0, '4': 26, '5': 1032, '6': 42, '7': 54, '8': 799, '9': 15, '10': 8, '11': 820, '12': 23, '13': 141, '14': 0, '15': 0}

# %% [markdown]
# # APLICAR SOBREMUESTREO

# %%
processor = Data_processing(datasetmanager.ruta_raiz_dataset)
antes = processor.count_class_distribution("Antes")
processor.oversample_rare_classes();
# Out:
# Distribución Detallada de Clases Antes:
# ================================================================================
#   ID Clase                   Train      Val     Test    Total  % Total
# --------------------------------------------------------------------------------
#    0 link                    15583     1563     2222    19368    64.48%
#    1 button                   5101      627      877     6605    21.99%
#    2 input                     354       54       44      452     1.50%
#    3 select                      0        0        0        0     0.00%
#    4 textarea                   26        8        3       37     0.12%
#    5 label                    1032       59       37     1128     3.76%
#    6 checkbox                   42        0        9       51     0.17%
#    7 radio                      54        6       16       76     0.25%
#    8 dropdown                  799       88       93      980     3.26%
#    9 slider                     15        2        1       18     0.06%
#   10 toggle                      8        0        0        8     0.03%
#   11 menu_item                 820      103      115     1038     3.46%
#   12 clickable                  23        5        1       29     0.10%
#   13 icon                      141       55       49      245     0.82%
#   14 image                       0        0        0        0     0.00%
#   15 text                        0        0        0        0     0.00%
# ================================================================================
# TOTAL INSTANCIAS             23998     2570     3467    30035  100.00%
#  Iniciando sobremuestreo AGRESIVO con factor_duplicacion=10...
# Modo: Sobremuestreo de TODAS las clases raras (conteo original < 100):
#   - textarea (ID: 4, Conteo Original: 26)
#   - checkbox (ID: 6, Conteo Original: 42)
#   - radio (ID: 7, Conteo Original: 54)
#   - slider (ID: 9, Conteo Original: 15)
#   - toggle (ID: 10, Conteo Original: 8)
#   - clickable (ID: 12, Conteo Original: 23)
#
# Se encontraron 54 imágenes únicas con clases objetivo para duplicar.
#  Se crearon 540 nuevos pares imagen/etiqueta exitosamente.

# %%
despues = processor.count_class_distribution("Despues")
# Out:
# Distribución Detallada de Clases Despues:
# ================================================================================
#   ID Clase                   Train      Val     Test    Total  % Total
# --------------------------------------------------------------------------------
#    0 link                    36683     1563     2222    40468    64.92%
#    1 button                  10961      627      877    12465    20.00%
#    2 input                    1074       54       44     1172     1.88%
#    3 select                      0        0        0        0     0.00%
#    4 textarea                  286        8        3      297     0.48%
#    5 label                    2552       59       37     2648     4.25%
#    6 checkbox                  462        0        9      471     0.76%
#    7 radio                     594        6       16      616     0.99%
#    8 dropdown                 1389       88       93     1570     2.52%
#    9 slider                    165        2        1      168     0.27%
#   10 toggle                     88        0        0       88     0.14%
#   11 menu_item                1420      103      115     1638     2.63%
#   12 clickable                 253        5        1      259     0.42%
#   13 icon                      371       55       49      475     0.76%
#   14 image                       0        0        0        0     0.00%
#   15 text                        0        0        0        0     0.00%
# ================================================================================
# TOTAL INSTANCIAS             56298     2570     3467    62335  100.00%

# %% [markdown]
# ## 3️⃣ **Entrenamiento del modelo**

# %%
from ultralytics import YOLO
datasetmanager.yaml_cambiar_carpeta(split="train",nuevaruta="train")
#Entrenar YOLO de manera clásica con el dataset train, para eso modifico la ruta en el dataset.yaml
model = YOLO("yolov8l.pt")  # yolov8l.pt.
# Cargar dataset usando YOLOv8 Dataset
carpeta_salida = "exp_5" #carpeta donde se van a guardar los resultados del entrenamiento de YOLO y el modelo
model.train(data=datasetmanager.ruta_yaml,
    epochs=100,         #epocas 100
    imgsz= (1920,1080), #tamaño a los que se redimensionara la imagen de entrada #(1920,1080) - 640
    batch=6,            #tamaño del batch (ajustarlo según Vram)
    optimizer="AdamW", #AdamW
    #momentum =0.72765,      # será ignorado si usa Adam/AdamW
    weight_decay = 0.00808107114573286,
    lr0= 0.00004694921598565255,
    lrf= 0.46315,
    name= carpeta_salida,   # nombre del run
    exist_ok=False,         # sobrescribe si ya existe
    project="/content/drive/MyDrive/MIA/Entrenamientos", #En Drive
    patience=15
)
# Out:
# 2025-10-23 00:00:06,592 - YOLODatasetManager - INFO - Ruta Split train actualizada correctamente a train/images en /content/dataset/dataset.yaml.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt': 100% ━━━━━━━━━━━━ 83.7MB 40.6MB/s 2.1s
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=6, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset/dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=(1920, 1080), int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=4.694921598565255e-05, lrf=0.46315, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=exp_5, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/MIA/Entrenamientos, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/MIA/Entrenamientos/exp_5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.00808107114573286, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 157.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=16
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5595136  ultralytics.nn.modules.head.Detect           [16, [256, 512, 512]]
# Model summary: 209 layers, 43,642,176 parameters, 43,642,160 gradients, 165.5 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 339.4MB/s 0.0s
# AMP: checks passed ✅
# WARNING ⚠️ updating to 'imgsz=1920'. 'train' and 'val' imgsz must be an integer, while 'predict' and 'export' imgsz may be a [h, w] list or an integer, i.e. 'yolo export imgsz=640,480' or 'yolo export imgsz=640'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2476.4±1011.9 MB/s, size: 284.4 KB)
# train: Scanning /content/dataset/train/labels... 1084 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1084/1084 946.2it/s 1.1s
# train: /content/dataset/train/images/ai_platforms_wandb.ai_1729627029.png: 29 duplicate labels removed
# train: /content/dataset/train/images/ai_platforms_wandb.ai_1729629963.png: 29 duplicate labels removed
# train: /content/dataset/train/images/creative_www.remove.bg_1729627000.png: 2 duplicate labels removed
# train: /content/dataset/train/images/creative_www.remove.bg_1729629925.png: 2 duplicate labels removed
# train: /content/dataset/train/images/creative_www.remove.bg_1729631855.png: 2 duplicate labels removed
# train: /content/dataset/train/images/dashboards_newrelic.com_1729626937.png: 2 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v1.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v10.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v2.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v3.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v4.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v5.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v6.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v7.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v8.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729626989_oversampled_v9.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v1.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v10.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v2.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v3.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v4.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v5.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v6.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v7.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v8.png: 5 duplicate labels removed
# train: /content/dataset/train/images/dev_tools_jsfiddle.net_1729631847_oversampled_v9.png: 5 duplicate labels removed
# train: /content/dataset/train/images/development_developer.mozilla.org_1729626875.png: 3 duplicate labels removed
# train: /content/dataset/train/images/documentation_kubernetes.io_1729626975.png: 146 duplicate labels removed
# train: /content/dataset/train/images/documentation_kubernetes.io_1729629736.png: 146 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.amazon.com_1729626821.png: 4 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.ebay.com_1729626822.png: 6 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.ebay.com_1729629594.png: 6 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v1.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v10.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v2.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v3.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v4.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v5.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v6.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v7.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v8.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www.newegg.com_1729626857_oversampled_v9.png: 1 duplicate labels removed
# train: /content/dataset/train/images/e_commerce_www
#        [   0.055556,    0.055556,    0.055556, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: np.float64(0.2517208933757917)
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.44098,     0.51996,     0.67927,     0.25172,     0.42306,     0.29418,     0.25172,           0,     0.26137,           0,     0.25172,    0.075344,    0.044011,    0.030757,     0.25172,     0.25172])
# names: {0: 'link', 1: 'button', 2: 'input', 3: 'select', 4: 'textarea', 5: 'label', 6: 'checkbox', 7: 'radio', 8: 'dropdown', 9: 'slider', 10: 'toggle', 11: 'menu_item', 12: 'clickable', 13: 'icon', 14: 'image', 15: 'text'}
# nt_per_class: array([1539,  583,   54,    0,    8,   59,    0,    6,   79,    2,    0,   89,    5,   54,    0,    0])
# nt_per_image: array([70, 61, 37,  0,  5, 18,  0,  2, 22,  2,  0,  6,  1,  8,  0,  0])
# results_dict: {'metrics/precision(B)': 0.7556620189068877, 'metrics/recall(B)': 0.2840109586249686, 'metrics/mAP50(B)': 0.32240797851420827, 'metrics/mAP50-95(B)': 0.2517208933757917, 'fitness': 0.2517208933757917}
# save_dir: PosixPath('/content/drive/MyDrive/MIA/Entrenamientos/exp_5')
# speed: {'preprocess': 0.5558044225400524, 'inference': 10.388683633824309, 'loss': 0.0008683521333347324, 'postprocess': 19.67413397177949}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'

# %% [markdown]
# ## 4️⃣ **Generación de todas las curvas requeridas**

# %%
# Crear objeto Visualizador
carpeta_salida = "exp_5"
visualizer = YOLOMetricasVisualizar(f"/content/drive/MyDrive/MIA/Entrenamientos/{carpeta_salida}/results.csv",
                                    f"/content/drive/MyDrive/MIA/Entrenamientos/{carpeta_salida}/weights/best.pt",datasetmanager.ruta_yaml)
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 112 layers, 43,618,944 parameters, 0 gradients, 164.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3042.7±1723.8 MB/s, size: 698.3 KB)
# val: Scanning /content/dataset/val/labels.cache... 71 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 71/71 139.3Kit/s 0.0s
# val: /content/dataset/val/images/dev_tools_jsfiddle.net_1729629915.png: 5 duplicate labels removed
# val: /content/dataset/val/images/development_developer.mozilla.org_1729626875.png: 3 duplicate labels removed
# val: /content/dataset/val/images/development_developer.mozilla.org_1729629644.png: 3 duplicate labels removed
# val: /content/dataset/val/images/e_commerce_www.amazon.com_1729629595.png: 4 duplicate labels removed
# val: /content/dataset/val/images/microsoft_office_www.office.com_1729629719.png: 1 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_amazon.co.jp_1729630376.png: 5 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_amazon.es_1729631358.png: 3 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_amazon.fr_1729630732.png: 3 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_cdc.gov_1729630509.png: 1 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_cnil.fr_1729631104.png: 24 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_fandom.com_1729630545.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_flickr.com_1729631650.png: 3 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_hubspot.com_1729631068.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_myspace.com_1729630320.png: 7 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_prezi.com_1729631294.png: 7 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_salesforce.com_1729631678.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_theglobeandmail.com_1729631693.png: 1 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_theverge.com_1729631411.png: 4 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_whitehouse.gov_1729630760.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_wikia.com_1729630954.png: 1 duplicate labels removed
# val: /content/dataset/val/images/office_learning_www.linkedin.com_1729629851.png: 5 duplicate labels removed
# val: /content/dataset/val/images/office_resources_templates.office.com_1729629859.png: 1 duplicate labels removed
# val: /content/dataset/val/images/productivity_trello.com_1729629613.png: 1 duplicate labels removed
# val: /content/dataset/val/images/web_apps_workspace.google.com_1729629912.png: 2 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.9it/s 5.9s
#                    all         71       2478      0.756      0.282      0.322      0.251
# Speed: 14.1ms preprocess, 16.3ms inference, 0.1ms loss, 18.0ms postprocess per image
# Results saved to /content/runs/detect/val

# %%
visualizer.plot_loss() # Graficar Loss
visualizer.gap_entretrainyval() # Graficar Gap
visualizer.plot_map()  # Graficar mAP
visualizer.plot_precision_recall_f1() # Graficar Precision, Recall, F1
visualizer.print_final_metrics() # Mostrar métricas finales
#Metricas por Clase
df = visualizer.metrics_por_clase_tabla()   # Imprime Precision, Recall, F1 y mAP50 por clase
display(df)
# Out:
# Final Metrics (last epoch):
# Precision: 0.7840
# Recall:    0.2800
# F1-score:  0.4126
#         Clase           Precision              Recall                  F1  \
# 0        link            0.684501            0.588044            0.632617
# 1      button            0.761866              0.5506             0.63923
# 2       input             0.92855            0.721998             0.81235
# 3      select  clase sin métricas  clase sin métricas  clase sin métricas
# 4    textarea             0.75163               0.375            0.500362
# 5       label            0.699359            0.474576            0.565447
# 6    checkbox  clase sin métricas  clase sin métricas  clase sin métricas
# 7       radio                 1.0                 0.0                 0.0
# 8    dropdown            0.727023            0.291139            0.415778
# 9      slider                 1.0                 0.0                 0.0
# 10     toggle  clase sin métricas  clase sin métricas  clase sin métricas
# 11  menu_item            0.202748            0.067416            0.101186
# 12  clickable                 1.0                 0.0                 0.0
# 13       icon            0.555219            0.037037            0.069442
# 14      image  clase sin métricas  clase sin métricas  clase sin métricas
# 15       text  clase sin métricas  clase sin métricas  clase sin métricas
#
#                  mAP50
# 0             0.595767
# 1             0.608736
# 2             0.761903
# 3   clase sin métricas
# 4             0.479878
# 5              0.52422
# 6   clase sin métricas
# 7                  0.0
# 8              0.33664
# 9                  0.0
# 10  clase sin métricas
# 11              0.0823
# 12            0.107701
# 13            0.044121
# 14  clase sin métricas
# 15  clase sin métricas

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/MIA/Entrenamientos/exp_1_f1/results.csv")
total_time = df["time"].sum()
num_epochs = len(df)
print(f"Tiempo total de entrenamiento 2: {total_time/60:.2f} minutos  epocas: {num_epochs}")
# Out:
# Tiempo total de entrenamiento 2: 752.58 minutos  epocas: 25

# %%
# Crear objeto Visualizador
carpeta_salida = "exp_1_f1"
visualizer = YOLOMetricasVisualizar(f"/content/drive/MyDrive/MIA/Entrenamientos/{carpeta_salida}/results.csv",
                                    f"/content/drive/MyDrive/MIA/Entrenamientos/{carpeta_salida}/weights/best.pt",datasetmanager.ruta_yaml)
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 112 layers, 43,618,944 parameters, 0 gradients, 164.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3013.8±1060.3 MB/s, size: 497.4 KB)
# val: Scanning /content/dataset/val/labels.cache... 71 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 71/71 157.9Kit/s 0.0s
# val: /content/dataset/val/images/dev_tools_jsfiddle.net_1729629915.png: 5 duplicate labels removed
# val: /content/dataset/val/images/development_developer.mozilla.org_1729626875.png: 3 duplicate labels removed
# val: /content/dataset/val/images/development_developer.mozilla.org_1729629644.png: 3 duplicate labels removed
# val: /content/dataset/val/images/e_commerce_www.amazon.com_1729629595.png: 4 duplicate labels removed
# val: /content/dataset/val/images/microsoft_office_www.office.com_1729629719.png: 1 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_amazon.co.jp_1729630376.png: 5 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_amazon.es_1729631358.png: 3 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_amazon.fr_1729630732.png: 3 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_cdc.gov_1729630509.png: 1 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_cnil.fr_1729631104.png: 24 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_fandom.com_1729630545.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_flickr.com_1729631650.png: 3 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_hubspot.com_1729631068.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_myspace.com_1729630320.png: 7 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_prezi.com_1729631294.png: 7 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_salesforce.com_1729631678.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_theglobeandmail.com_1729631693.png: 1 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_theverge.com_1729631411.png: 4 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_whitehouse.gov_1729630760.png: 2 duplicate labels removed
# val: /content/dataset/val/images/mostvisited_wikia.com_1729630954.png: 1 duplicate labels removed
# val: /content/dataset/val/images/office_learning_www.linkedin.com_1729629851.png: 5 duplicate labels removed
# val: /content/dataset/val/images/office_resources_templates.office.com_1729629859.png: 1 duplicate labels removed
# val: /content/dataset/val/images/productivity_trello.com_1729629613.png: 1 duplicate labels removed
# val: /content/dataset/val/images/web_apps_workspace.google.com_1729629912.png: 2 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.2s
#                    all         71       2478      0.424     0.0525     0.0674     0.0425
# Speed: 5.9ms preprocess, 7.7ms inference, 0.0ms loss, 19.7ms postprocess per image
# Results saved to /content/runs/detect/val2

# %%
visualizer.plot_loss() # Graficar Loss
visualizer.gap_entretrainyval() # Graficar Gap
visualizer.plot_map()  # Graficar mAP
visualizer.plot_precision_recall_f1() # Graficar Precision, Recall, F1
visualizer.print_final_metrics() # Mostrar métricas finales
#Metricas por Clase
df = visualizer.metrics_por_clase_tabla()   # Imprime Precision, Recall, F1 y mAP50 por clase
display(df)
# Out:
# Final Metrics (last epoch):
# Precision: 0.4516
# Recall:    0.0892
# F1-score:  0.1490
#         Clase           Precision              Recall                  F1  \
# 0        link            0.255096            0.252112            0.253595
# 1      button            0.407643            0.325901            0.362217
# 2       input                 1.0                 0.0                 0.0
# 3      select  clase sin métricas  clase sin métricas  clase sin métricas
# 4    textarea                 0.0                 0.0                 0.0
# 5       label                 1.0                 0.0                 0.0
# 6    checkbox  clase sin métricas  clase sin métricas  clase sin métricas
# 7       radio                 0.0                 0.0                 0.0
# 8    dropdown                 1.0                 0.0                 0.0
# 9      slider                 0.0                 0.0                 0.0
# 10     toggle  clase sin métricas  clase sin métricas  clase sin métricas
# 11  menu_item                 1.0                 0.0                 0.0
# 12  clickable                 0.0                 0.0                 0.0
# 13       icon                 0.0                 0.0                 0.0
# 14      image  clase sin métricas  clase sin métricas  clase sin métricas
# 15       text  clase sin métricas  clase sin métricas  clase sin métricas
#
#                  mAP50
# 0             0.167567
# 1             0.268716
# 2             0.068312
# 3   clase sin métricas
# 4                  0.0
# 5             0.179488
# 6   clase sin métricas
# 7                  0.0
# 8                  0.0
# 9                  0.0
# 10  clase sin métricas
# 11            0.057333
# 12                 0.0
# 13                 0.0
# 14  clase sin métricas
# 15  clase sin métricas
